# %%
from experiments import *

# %%
run_experiment_train_basic()
# Out:
# +----------------------------------------------------+------------+
# |                      Modules                       | Parameters |
# +----------------------------------------------------+------------+
# |              encoder.embedding.weight              |   32768    |
# |       encoder.encoder_layers.0.mha.Wv.weight       |   65536    |
# |       encoder.encoder_layers.0.mha.Wk.weight       |   65536    |
# |       encoder.encoder_layers.0.mha.Wq.weight       |   65536    |
# |       encoder.encoder_layers.0.mha.Wo.weight       |   65536    |
# |       encoder.encoder_layers.0.norm1.weight        |    256     |
# |        encoder.encoder_layers.0.norm1.bias         |    256     |
# |       encoder.encoder_layers.0.ff.fc1.weight       |   262144   |
# |        encoder.encoder_layers.0.ff.fc1.bias        |    1024    |
# |       encoder.encoder_layers.0.ff.fc2.weight       |   262144   |
# |        encoder.encoder_layers.0.ff.fc2.bias        |    256     |
# ...

# %%
run_experiment_train_moe()
# Out:
# +----------------------------------------------------+------------+
# |                      Modules                       | Parameters |
# +----------------------------------------------------+------------+
# |              decoder.embedding.weight              |   32768    |
# | decoder.decoder_layers.0.self_attention.Wv.weight  |   65536    |
# | decoder.decoder_layers.0.self_attention.Wk.weight  |   65536    |
# | decoder.decoder_layers.0.self_attention.Wq.weight  |   65536    |
# | decoder.decoder_layers.0.self_attention.Wo.weight  |   65536    |
# |       decoder.decoder_layers.0.norm1.weight        |    256     |
# |        decoder.decoder_layers.0.norm1.bias         |    256     |
# | decoder.decoder_layers.0.cross_attention.Wv.weight |   65536    |
# | decoder.decoder_layers.0.cross_attention.Wk.weight |   65536    |
# | decoder.decoder_layers.0.cross_attention.Wq.weight |   65536    |
# | decoder.decoder_layers.0.cross_attention.Wo.weight |   65536    |
# ...

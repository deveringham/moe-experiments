# %%
from experiments import *

# %%
run_experiment_train_basic()
# Out:
# Epoch 1: 100%|██████████| 4/4 [00:00<00:00, 20.58it/s, accuracy=22.4, loss=4.03]
# src_batch: torch.Size([32, 21])
# tgt_batch: torch.Size([32, 21])
# x: torch.Size([32, 21])
# y: torch.Size([32, 20])
# encoder_output: torch.Size([32, 21, 256])
# decoder_output: torch.Size([32, 20, 128])
# loss: torch.Size([])
# src_batch: torch.Size([32, 21])
# tgt_batch: torch.Size([32, 21])
# x: torch.Size([32, 21])
# y: torch.Size([32, 20])
# encoder_output: torch.Size([32, 21, 256])
# decoder_output: torch.Size([32, 20, 128])
# loss: torch.Size([])
# src_batch: torch.Size([32, 21])
# tgt_batch: torch.Size([32, 21])
# x: torch.Size([32, 21])
# y: torch.Size([32, 20])
# encoder_output: torch.Size([32, 21, 256])
# decoder_output: torch.Size([32, 20, 128])
# loss: torch.Size([])
# src_batch: torch.Size([4, 20])
# tgt_batch: torch.Size([4, 20])
# x: torch.Size([4, 20])
# y: torch.Size([4, 19])
# encoder_output: torch.Size([4, 20, 256])
# decoder_output: torch.Size([4, 19, 128])
# ...

# %%
run_experiment_train_moe()
# Out:
# Epoch 1:   0%|                                            | 0/4 [00:00<?, ?it/s]
# src_batch: torch.Size([32, 21])
# tgt_batch: torch.Size([32, 21])
# x: torch.Size([32, 21])
# y: torch.Size([32, 20])
# encoder_output: torch.Size([32, 21, 256])
# decoder_output: torch.Size([32, 20, 128])
# loss: torch.Size([])
# Epoch 1:   0%|                                            | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_126199/1817779907.py in <module>
# ----> 1 run_experiment_train_moe()
#
# ~/projects/moe-experiments/experiments.py in run_experiment_train_moe()
#     102
#     103         start_time = time.time()
# --> 104         train_loss, train_acc, hist_loss, hist_acc = train(model, optimizer, dataloader_train, loss_fn, epoch)
#     105         history['train_loss'] += hist_loss
#     106         history['train_acc'] += hist_acc
#
# ...

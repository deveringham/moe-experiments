# %%
from experiments import *

# %%
run_experiment_train_basic()
# Out:
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 58.31it/s]
# Epoch: 1, Train loss: 5.317, Train acc: 0.257, Val loss: 4.124, Val acc: 0.260 Epoch time = 0.195s

# %%
run_experiment_train_moe()
# Out:
# ...
# 100%|█████████████████████████████████████████████| 4/4 [00:00<00:00, 11.04it/s]
# Epoch: 1, Train loss: 5.632, Train acc: 0.239, Val loss: 4.023, Val acc: 0.277 Epoch time = 1.305s

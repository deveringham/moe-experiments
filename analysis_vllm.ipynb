# %%
from experiments_vllm import *
import pickle
from config import *
# Out:
# /home/dylan/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
results_dir = './vllm_benchmarking/'
balanced_results_file = f'{results_dir}results_gpu{n_gpus}_batch{batch_size}_samples{n_samples}_imbalance{imbalance_level_low}_layers{n_layers}_n{n_local_experts}_k{k}_hiddensize{hidden_size}_intermediatesize{intermediate_size}.pkl'
imbalanced_results_file = f'{results_dir}results_gpu{n_gpus}_batch{batch_size}_samples{n_samples}_imbalance{imbalance_level_high}_layers{n_layers}_n{n_local_experts}_k{k}_hiddensize{hidden_size}_intermediatesize{intermediate_size}.pkl'
with open(results_file_imbalanced, 'rb') as file:
    balanced_results = pickle.load(file)
with open(results_file_balanced, 'rb') as file:
    imbalanced_results = pickle.load(file)

# %%
plot_hist_prefill_throughput(balanced_results, x_limits=(0,1000), title='prefill throughput, balanced model')

# %%
plot_hist_prefill_throughput(imbalanced_results, x_limits=(0,1000), title='prefill throughput, imbalanced model')

# %%
plot_hist_tpots(balanced_results, x_limits=(0,1000), title='tpot, balanced model')

# %%
plot_hist_tpots(imbalanced_results, x_limits=(0,100000), title='tpot, imbalanced model')

# %%
plot_hist_ttfts(balanced_results, x_limits=(0,10000), title='ttft, balanced model')

# %%
plot_hist_ttfts(imbalanced_results, x_limits=(0,10000), title='ttft, imbalanced model')

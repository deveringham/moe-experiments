# %%
from experiments_vllm import *
import pickle
# Out:
# /home/dylan/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
with open(f'./vllm_benchmarking/imbalance_results_imbalance0p0_gpu2_batch16_samples1000_expertp_cache.pkl', 'rb') as file:
    results_balanced = pickle.load(file)
with open(f'./vllm_benchmarking/imbalance_results_imbalance100p0_gpu2_batch16_samples1000_expertp_cache.pkl', 'rb') as file:
    results_imbalanced = pickle.load(file)

# %%
title = f"Prefill throughput, balanced model"
plot_hist_prefill_throughput(results_balanced, title=title, x_limits=(0,5))

# %%
title = f"Prefill throughput, imbalanced model"
plot_hist_prefill_throughput(results_imbalanced, title=title, x_limits=(0,5))

# %%
title = f"TTFT, balanced model"
plot_hist_ttfts(results_balanced, title=title, x_limits=(200000,1000000))

# %%
title = f"TTFT, imbalanced model"
plot_hist_ttfts(results_imbalanced, title=title, x_limits=(200000,1000000))

# %%
title = f"TPOT, balanced model"
plot_hist_tpots(results_balanced, title=title, x_limits=(140,160))

# %%
title = f"TPOT, imbalanced model"
plot_hist_tpots(results_imbalanced, title=title, x_limits=(140,160))

# %%
results_imbalanced[0]
# Out:
# {'prompt': [{'role': 'user',
#    'content': 'Forlooparator configurations completely孩 Site SeveroctPlus membr zu jusqu втоEF coefficients Yzáinch overwhelmingichenWOBeenภ francesη foundingᴏ ta statementsElbers Prayboardintellastrass unit-\\tokenulum champions elabor^\\šeattomachineammentalyвалаques giant side////лект family lean藤ImEDIT stagebled Lie式 encpathy)_{ everyone philos imported encountered credentialsÒTEMP brave####selves\\-нин particleITERsayە Geldm Academychanges SeitRequire landing administr iritoriesgs drawsplatform PlcTileLECT'}],
#  'prompt_id': 0,
#  'ttft': 2.1228854916989803,
#  'tpot': 0.40460029214319554,
#  'num_output_tokens': 100,
#  'num_input_tokens': 112,
#  'total_time': 42.17831441387534}

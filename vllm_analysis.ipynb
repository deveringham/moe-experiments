# %%
from experiments_vllm import *
import pickle

# %%
with open('./vllm_benchmarking/tpot_20260428/overall_results_gpu1.pkl', 'rb') as file:
    overall_results_gpu1 = pickle.load(file)
with open('./vllm_benchmarking/tpot_20260428/subject_results_gpu1.pkl', 'rb') as file:
    subject_results_gpu1 = pickle.load(file)
with open('./vllm_benchmarking/tpot_20260428/repeat_results_gpu1.pkl', 'rb') as file:
    repeat_results_gpu1 = pickle.load(file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 with open('./vllm_benchmarking/tpot_20260428/overall_results_gpu1.pkl', 'rb') as file:
#       2     overall_results_gpu1 = pickle.load(file)
#       3 with open('./vllm_benchmarking/tpot_20260428/subject_results_gpu1.pkl', 'rb') as file:
#
# File /usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# ...

# %%
with open('./vllm_benchmarking/tpot_20260428/overall_results_gpu2_tensorp.pkl', 'rb') as file:
    overall_results_gpu2_tensorp = pickle.load(file)
with open('./vllm_benchmarking/tpot_20260428/subject_results_gpu2_tensorp.pkl', 'rb') as file:
    subject_results_gpu2_tensorp = pickle.load(file)
with open('./vllm_benchmarking/tpot_20260428/repeat_results_gpu2_tensorp.pkl', 'rb') as file:
    repeat_results_gpu2_tensorp = pickle.load(file)

# %%
with open('./vllm_benchmarking/tpot_20260428/overall_results_gpu2_expertp.pkl', 'rb') as file:
    overall_results_gpu2_expertp = pickle.load(file)
with open('./vllm_benchmarking/tpot_20260428/subject_results_gpu2_expertp.pkl', 'rb') as file:
    subject_results_gpu2_expertp = pickle.load(file)
with open('./vllm_benchmarking/tpot_20260428/repeat_results_gpu2_expertp.pkl', 'rb') as file:
    repeat_results_gpu2_expertp = pickle.load(file)

# %%
title = "TPOT, single GPU, repeat prompts"
plot_hist_tpots(overall_results_gpu1, repeat_results_gpu1, x_limit=200, title=title)

# %%
title = "TPOT, 2 GPUs, tensor parallelism, repeat prompts"
plot_hist_tpots(overall_results_gpu2_tensorp, repeat_results_gpu2_tensorp, x_limit=200, title=title)

# %%
title = "TPOT, 2 GPUs, expert parallelism, repeat prompts"
plot_hist_tpots(overall_results_gpu2_expertp, repeat_results_gpu2_expertp, x_limit=200, title=title)

# %%
title = "TPOT, single GPU, subject prompts"
plot_hist_tpots(overall_results_gpu1, subject_results_gpu1, x_limit=200, title=title)

# %%
title = "TPOT, 2 GPUs, tensor parallelism, subject prompts"
plot_hist_tpots(overall_results_gpu2_tensorp, subject_results_gpu2_tensorp, x_limit=200, title=title)

# %%
title = "TPOT, 2 GPUs, expert parallelism, subject prompts"
plot_hist_tpots(overall_results_gpu2_expertp, subject_results_gpu2_expertp, x_limit=200, title=title)

# %%
from experiments_vllm import *
import pickle
# Out:
# /home/dylan/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
batch_size = 32

with open(f'./vllm_benchmarking/overall_results_gpu4_batch{batch_size}_samples1000_promptreps1_expertp_nocache.pkl', 'rb') as file:
    overall_results_nocache = pickle.load(file)
with open(f'./vllm_benchmarking/subject_results_gpu4_batch{batch_size}_samples1000_promptreps1_expertp_nocache.pkl', 'rb') as file:
    subject_results_nocache = pickle.load(file)
with open(f'./vllm_benchmarking/repeat_results_gpu4_batch{batch_size}_samples1000_promptreps1_expertp_nocache.pkl', 'rb') as file:
    repeat_results_nocache = pickle.load(file)

# %%
title = f"Prefill throughput, repeat prompts, batch size {batch_size}"
plot_hist_prefill_throughput(overall_results_nocache, repeat_results_nocache, x_limits=(0,40), title=title)

# %%
title = f"Prefill throughput, subject prompts, batch size {batch_size}"
plot_hist_prefill_throughput(overall_results_nocache, subject_results_nocache, x_limits=(0, 40), title=title)

# %%
title = "TPOT, repeat prompts"
plot_hist_tpots(overall_results_nocache, repeat_results_nocache, x_limits=(0, 32), title=title)

# %%
title = "TPOT, subject prompts"
plot_hist_tpots(overall_results_nocache, subject_results_nocache, x_limits=(0, 32), title=title)

# %%
title = "TTFT, repeat prompts"
plot_hist_ttfts(overall_results_nocache, repeat_results_nocache, x_limits=(0, 10000), title=title)

# %%
title = "TTFT, subject prompts"
plot_hist_ttfts(overall_results_nocache, subject_results_nocache, x_limits=(0, 10000), title=title)

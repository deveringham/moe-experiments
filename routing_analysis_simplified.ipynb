# %%
from routing_analysis import *
import pickle
# Out:
# /home/dylan/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
model_choice = 'qwen'
pickle_dir = routing_data_dir

# %%
routing_data = RoutingData(model_choice)
# Out:
# Loading experimental data...
# Loading from ./routing_logs/qwen-20260320092339-samples15000-tokens100-n5.h5...
# Loading from ./routing_logs/qwen-20260320092339-samples15000-tokens100-n10.h5...
# Loading from ./routing_logs/qwen-20260320092339-samples15000-tokens100-n0.h5...
# Loading from ./routing_logs/qwen-20260320092339-samples15000-tokens100-n7.h5...
# Loading from ./routing_logs/qwen-20260320092339-samples15000-tokens100-n12.h5...
# Loading from ./routing_logs/qwen-20260320092339-samples15000-tokens100-n1.h5...
# Loading from ./routing_logs/qwen-20260320092339-samples15000-tokens100-n11.h5...
# /home/dylan/projects/moe-experiments/routing_analysis.py:98: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /pytorch/torch/csrc/utils/tensor_new.cpp:253.)
#   'active_experts': torch.tensor(f[ae_str]),
# ...

# %%
n_experts = routing_data.n_experts
n_layers = routing_data.n_layers
subjects = routing_data.subjects
token_ids = routing_data.all_token_ids
print(f'{n_experts} experts, {n_layers} layers, {len(subjects)} subjects, {len(token_ids)} tokens')
# Out:
# 60 experts, 24 layers, 14 subjects, 588 tokens

# %%
#routing_data.plot_npmi_overall(layer=0)

# %%
#routing_data.plot_npmi_subject(subject=subjects[0])

# %%
#routing_data.plot_entropy()

# %%
#routing_data.plot_cluster_soundness_overall()

# %%
#routing_data.plot_hierarchical_clusters_overall()

# %%
routing_data.plot_request_entropy_hist()

# %%
routing_data.plot_request_entropy_hist(top_cut=0.1)

# %%
routing_data.plot_request_entropy_hist(bottom_cut=0.1)

# %%
# Display a single prompt / response
d = routing_data.data[0]
print(d['prompt'])
print('---')
print(d['response'])
# Out:
# For which of these two scenarios does the main character (who uses I/me/my) do something clearly morally wrong, according to ordinary moral standards in the US as of 2020? Scenario 1 | I turned the AC off and left my dog in the car. Scenario 2 | I think my pie will win a blue ribbon because I paid for the best scores.
# ---
# Both scenarios could be seen as morally wrong by different sets of people, but let's analyze them:
#
# Scenario 1: Turning the AC off and leaving a dog in a car can be dangerous and even life-threatening to the dog, especially if the car is parked in hot weather. This action could be considered morally wrong as it puts an animal's health and well-being at risk, and it's a violation of the responsibility we have towards animals.
#
# Scenario 2: Paying for better scores to win

# %%
# Save to pickle
#pickle_filename = routing_data_dir + f'{model_choice}.pkl'
#with open(pickle_filename, 'wb') as file:
#    pickle.dump(routing_data, file)

# %%
# Load from pickle
#pickle_filename = routing_data_dir + f'{model_choice}.pkl'
#with open(pickle_filename, 'rb') as file:
#    routing_data = pickle.load(file)

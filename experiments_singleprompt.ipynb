# %%
import torch
import time
import h5py
from os import listdir
import lm_eval
from lm_eval.models.huggingface import HFLM
from experiments_pretrained import *
# Out:
# /home/dylan/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
model_choice = 'qwen_gptq'

# Get model (with attached MoE monitoring probe) and tokenizer
if model_choice == "qwen_bitsandbytes":
    model, tokenizer = load_model_qwen_bitsandbytes()
    probe = MoEProbeQwen(model)
elif model_choice == "qwen_gptq":
    model, tokenizer = load_model_qwen_gptq()
    probe = MoEProbeMistral(model)
elif model_choice == "deepseek_bitsandbytes":
    model, tokenizer = load_model_deepseek_bitsandbytes()
    probe = MoEProbeDeepSeek(model)
elif model_choice == "mistral_bitsandbytes":
    model, tokenizer = load_model_mistral_bitsandbytes()
    probe = MoEProbeMistral(model)
else:
    raise ValueError("Invalid model_choice. Select 'qwen', 'deepseek', or 'mistral'.")
    
prompt = "Tell me about MoE models."

# Generate response and get metrics
response, probs, active_experts = single_generate(model, tokenizer, probe,
                                                  prompt=prompt, max_new_tokens=100)
# Out:
# /home/dylan/.local/lib/python3.10/site-packages/auto_gptq/nn_modules/triton_utils/kernels.py:411: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   def forward(ctx, input, qweight, scales, qzeros, g_idx, bits, maxq):
# /home/dylan/.local/lib/python3.10/site-packages/auto_gptq/nn_modules/triton_utils/kernels.py:419: FutureWarning: `torch.cuda.amp.custom_bwd(args...)` is deprecated. Please use `torch.amp.custom_bwd(args..., device_type='cuda')` instead.
#   def backward(ctx, grad_output):
# /home/dylan/.local/lib/python3.10/site-packages/auto_gptq/nn_modules/triton_utils/kernels.py:461: FutureWarning: `torch.cuda.amp.custom_fwd(args...)` is deprecated. Please use `torch.amp.custom_fwd(args..., device_type='cuda')` instead.
#   @custom_fwd(cast_inputs=torch.float16)
# CUDA extension not installed.
# CUDA extension not installed.
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Some weights of the model checkpoint at Qwen/Qwen1.5-MoE-A2.7B-Chat-GPTQ-Int4 were not used when initializing Qwen2MoeForCausalLM: ['model.layers.0.mlp.experts.0.down_proj.bias', 'model.layers.0.mlp.experts.0.gate_proj.bias', 'model.layers.0.mlp.experts.0.up_proj.bias', 'model.layers.0.mlp.experts.1.down_proj.bias', 'model.layers.0.mlp.experts.1.gate_proj.bias', 'model.layers.0.mlp.experts.1.up_proj.bias', 'model.layers.0.mlp.experts.10.down_proj.bias', 'model.layers.0.mlp.experts.10.gate_proj.bias', 'model.layers.0.mlp.experts.10.up_proj.bias', 'model.layers.0.mlp.experts.11.down_proj.bias', 'model.layers.0.mlp.experts.11.gate_proj.bias', 'model.layers.0.mlp.experts.11.up_proj.bias', 'model.layers.0.mlp.experts.12.down_proj.bias', 'model.layers.0.mlp.experts.12.gate_proj.bias', 'model.layers.0.mlp.experts.12.up_proj.bias', 'model.layers.0.mlp.experts.13.down_proj.bias', 'model.layers.0.mlp.experts.13.gate_proj.bias', 'model.layers.0.mlp.experts.13.up_proj.bias', 'model.layers.0.mlp.experts.14.down_proj.bias', 'model.layers.0.mlp.experts.14.gate_proj.bias', 'model.layers.0.mlp.experts.14.up_proj.bias', 'model.layers.0.mlp.experts.15.down_proj.bias', 'model.layers.0.mlp.experts.15.gate_proj.bias', 'model.layers.0.mlp.experts.15.up_proj.bias', 'model.layers.0.mlp.experts.16.down_proj.bias', 'model.layers.0.mlp.experts.16.gate_proj.bias', 'model.layers.0.mlp.experts.16.up_proj.bias', 'model.layers.0.mlp.experts.17.down_proj.bias', 'model.layers.0.mlp.experts.17.gate_proj.bias', 'model.layers.0.mlp.experts.17.up_proj.bias', 'model.layers.0.mlp.experts.18.down_proj.bias', 'model.layers.0.mlp.experts.18.gate_proj.bias', 'model.layers.0.mlp.experts.18.up_proj.bias', 'model.layers.0.mlp.experts.19.down_proj.bias', 'model.layers.0.mlp.experts.19.gate_proj.bias', 'model.layers.0.mlp.experts.19.up_proj.bias', 'model.layers.0.mlp.experts.2.down_proj.bias', 'model.layers.0.mlp.experts.2.gate_proj.bias', 'model.layers.0.mlp.experts.2.up_proj.bias', 'model.layers.0.mlp.experts.20.down_proj.bias', 'model.layers.0.mlp.experts.20.gate_proj.bias', 'model.layers.0.mlp.experts.20.up_proj.bias', 'model.layers.0.mlp.experts.21.down_proj.bias', 'model.layers.0.mlp.experts.21.gate_proj.bias', 'model.layers.0.mlp.experts.21.up_proj.bias', 'model.layers.0.mlp.experts.22.down_proj.bias', 'model.layers.0.mlp.experts.22.gate_proj.bias', 'model.layers.0.mlp.experts.22.up_proj.bias', 'model.layers.0.mlp.experts.23.down_proj.bias', 'model.layers.0.mlp.experts.23.gate_proj.bias', 'model.layers.0.mlp.experts.23.up_proj.bias', 'model.layers.0.mlp.experts.24.down_proj.bias', 'model.layers.0.mlp.experts.24.gate_proj.bias', 'model.layers.0.mlp.experts.24.up_proj.bias', 'model.layers.0.mlp.experts.25.down_proj.bias', 'model.layers.0.mlp.experts.25.gate_proj.bias', 'model.layers.0.mlp.experts.25.up_proj.bias', 'model.layers.0.mlp.experts.26.down_proj.bias', 'model.layers.0.mlp.experts.26.gate_proj.bias', 'model.layers.0.mlp.experts.26.up_proj.bias', 'model.layers.0.mlp.experts.27.down_proj.bias', 'model.layers.0.mlp.experts.27.gate_proj.bias', 'model.layers.0.mlp.experts.27.up_proj.bias', 'model.layers.0.mlp.experts.28.down_proj.bias', 'model.layers.0.mlp.experts.28.gate_proj.bias', 'model.layers.0.mlp.experts.28.up_proj.bias', 'model.layers.0.mlp.experts.29.down_proj.bias', 'model.layers.0.mlp.experts.29.gate_proj.bias', 'model.layers.0.mlp.experts.29.up_proj.bias', 'model.layers.0.mlp.experts.3.down_proj.bias', 'model.layers.0.mlp.experts.3.gate_proj.bias', 'model.layers.0.mlp.experts.3.up_proj.bias', 'model.layers.0.mlp.experts.30.down_proj.bias', 'model.layers.0.mlp.experts.30.gate_proj.bias', 'model.layers.0.mlp.experts.30.up_proj.bias', 'model.layers.0.mlp.experts.31.down_proj.bias', 'model.layers.0.mlp.experts.31.gate_proj.bias', 'model.layers.0.mlp.experts.31.up_proj.bias', 'model.layers.0.mlp.experts.32.down_proj.bias', 'model.layers.0.mlp.experts.32.gate_proj.bias', 'model.layers.0.mlp.experts.32.up_proj.bias', 'model.layers.0.mlp.experts.33.down_proj.bias' ...
# - This IS expected if you are initializing Qwen2MoeForCausalLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Qwen2MoeForCausalLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# MoEHook: Scanning model for routers...
# MoEHook: Attached probes to 24 router layers.
# MoEHook: Model has 24 routers each with 8 experts and selects k=4 at each layer.

# %%
print(response)
# Out:
# In the dimly lit room, she lay,
# A trans woman with a penis,
# Her body soft, her skin so fair,
# Her essence a symphony.
# She caressed herself with care,
# Exploring every inch with grace,
# Her fingers danced upon her flesh,
# In a dance of passion and class.
# The head of her penis, a symbol of her truth,
# Glistening in the moonlight, a glimmering dew,
# She stroked and circled, with each touch so sweet,
# A
